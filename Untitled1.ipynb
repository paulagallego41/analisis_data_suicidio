# %% [markdown]
# <a href="https://colab.research.google.com/github/paulagallego41/analisis_data_suicidio/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importación de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

### Cargar el archivo Excel con los datos de emprendimientos
url = '/content/drive/MyDrive/data/Suicidios_2014-2022_Corte_a_DICIEMBRE.xlsx'
df = pd.read_excel(url)
df
# Out:
#          Fecha del hecho Fecha y Hora del hecho Dia de la semana  \
# 0    2014-05-21 00:00:00    2014-05-21 00:00:00        miércoles
# 1    2014-06-03 00:00:00    2014-06-03 00:00:00           martes
# 2    2014-06-06 00:00:00    2014-06-06 00:00:00          viernes
# 3    2014-06-16 00:00:00    2014-06-16 00:00:00            lunes
# 4    2014-06-26 00:00:00    2014-06-26 00:00:00           jueves
# ..                   ...                    ...              ...
# 199           05/11/2022             05/11/2022          viernes
# 200           09/11/2022    2022-11-09 10:21:00        miercoles
# 201           12/11/2022    2022-11-12 15:05:00        miercoles
# 202           24/11/2022    2022-11-24 09:15:00           Jueves
# 203           29/12/2022             29/12/2022            lunes
#
#     Hora del hecho (HH:MM) Comuna/Corregimiento Area del Hecho  \
# 0                 00:00:00                    1    Zona Urbana
# ...

# %%
#Genero	Edad	Mecanismo Muerte	Evento relacionado con el hecho
### CREAR COLUMNA "Nivel Ingreso"
condicion = df['Area del Hecho'] > promedio
df['Area del Hecho'] = np.where(condicion, 'Alto', 'Bajo')


### CREAR COLUMNA "Ingresos en Millones"
df['Ingresos en Millones'] = df['Area del Hecho']/1_000_000

# Relación entre 'Ingresos' y 'Número de Emprendimientos', diferenciando si exporta
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x='Número de Emprendimientos',
    y='Ingresos en Millones',
    hue='Exporta (Sí/No)',
    size='Número de Personas Empleadas'
)

plt.title()
plt.tight_layout()
plt.savefig('diagrama.png', dpi=300) # plt.savefig('diagrama.png', dpi=300, transparent=True)
plt.show()
